# %% [markdown]
# ## Many Options
#
# There are many options when it comes to producing data visualizations:
#
# * ggplot - R, python
# * matplotlib - python
# * bokeh - python, R, scala
#
# We are going to look at bokeh since it has an API for Python, R and Scala.  It is modern, based on grammar of graphics, designed for the web.  I think it has higher ROL(return on learning) and a lovely logo:
#
# ![Bokeh](http://bokeh.pydata.org/en/latest/_static/images/logo.png)
#
# Lots of resources for bokeh online - start [here](http://bokeh.pydata.org/en/latest/).
#
# Majority of content in this section is a mash up of the content on the Bokeh site.
#
#
# ## Bokeh Charts
#
# Bokeh has 3 levels of interface for different users:
#
# * a low-level [bokeh.models](http://bokeh.pydata.org/en/latest/docs/reference/models.html#bokeh-models) interface that provides the most flexibility to application developers.
# * an intermediate-level [bokeh.plotting](http://bokeh.pydata.org/en/latest/docs/reference/plotting.html#bokeh-plotting) interface centered around composing visual glyphs.
# * a high-level [bokeh.charts](http://bokeh.pydata.org/en/latest/docs/reference/charts.html#bokeh-charts) interface to build complex statistical plots quickly and simply.
#
# We are going to take a very quick look at bokeh.charts - creating a bar chart, histogram, line chart, scatter chart and a boxplot.  Note we are only scratching the surface - I recommend learning bokeh.plotting when you have time.
#
# For many more details on bokeh.charts read the great documentation [here](http://bokeh.pydata.org/en/latest/docs/user_guide/charts.html).
#
# ### Input Data
#
# Charts uses [Pandas DataFrame](http://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.html#pandas.DataFrame) internally, so any inputs provided will be coerced into this format.
#
# The input types accepted are:
#
# Array-like: 1..* list, tuple, numpy.ndarray, pandas.Series
#
# Table-like:
#
#         records: a list(dict)
#         columns: a dict(list), pandas.DataFrame, or blaze resource
#
# Additional information - [10 Minute Intro to Panda's Data Frame](http://pandas.pydata.org/pandas-docs/stable/10min.html).

# %% [markdown]
# # Bar charts
#
# We are using bokeh.charts as well as a sample data set containing auto mpg data.
#
# We also set the chart size defaults and redirect plots to show up in the notebook:

# %%
from bokeh.charts import defaults, Bar, output_notebook, show
from bokeh.sampledata.autompg import autompg as df

defaults.plot_width = 500
defaults.plot_height = 300

output_notebook(hide_banner=True)

df.head()
# Out:
#     <script type="text/javascript">
#
#       (function(global) {
#         function now() {
#           return new Date();
#         }
#
#         if (typeof (window._bokeh_onload_callbacks) === "undefined") {
#           window._bokeh_onload_callbacks = [];
#         }
#
#         function run_callbacks() {
#           window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#           delete window._bokeh_onload_callbacks
#           console.info("Bokeh: all callbacks have finished");
#         }
#
#         function load_libs(js_urls, callback) {
#           window._bokeh_onload_callbacks.push(callback);
#           if (window._bokeh_is_loading > 0) {
#             console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#             return null;
#           }
#           if (js_urls == null || js_urls.length === 0) {
#             run_callbacks();
#             return null;
#           }
#           console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#           window._bokeh_is_loading = js_urls.length;
#           for (var i = 0; i < js_urls.length; i++) {
#             var url = js_urls[i];
#             var s = document.createElement('script');
#             s.src = url;
#             s.async = false;
#             s.onreadystatechange = s.onload = function() {
#               window._bokeh_is_loading--;
#               if (window._bokeh_is_loading === 0) {
#                 console.log("Bokeh: all BokehJS libraries loaded");
#                 run_callbacks()
#               }
#             };
#             s.onerror = function() {
#               console.warn("failed to load library " + url);
#             };
#             console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#             document.getElementsByTagName("head")[0].appendChild(s);
#           }
#         };var js_urls = ['https://cdn.pydata.org/bokeh/release/bokeh-0.11.0.min.js', 'https://cdn.pydata.org/bokeh/release/bokeh-widgets-0.11.0.min.js', 'https://cdn.pydata.org/bokeh/release/bokeh-compiler-0.11.0.min.js'];
#
#         var inline_js = [
#           function(Bokeh) {
#             Bokeh.set_log_level("info");
#           },
#           function(Bokeh) {
#             console.log("Bokeh: injecting CSS: https://cdn.pydata.org/bokeh/release/bokeh-0.11.0.min.css");
#             Bokeh.embed.inject_css("https://cdn.pydata.org/bokeh/release/bokeh-0.11.0.min.css");
#             console.log("Bokeh: injecting CSS: https://cdn.pydata.org/bokeh/release/bokeh-widgets-0.11.0.min.css");
#             Bokeh.embed.inject_css("https://cdn.pydata.org/bokeh/release/bokeh-widgets-0.11.0.min.css");
#           }
#         ];
#
#         function run_inline_js() {
#           for (var i = 0; i < inline_js.length; i++) {
#             inline_js[i](window.Bokeh);
#           }
#         }
#
#         if (window._bokeh_is_loading === 0) {
#           console.log("Bokeh: BokehJS loaded, going straight to plotting");
#           run_inline_js();
#         } else {
#           load_libs(js_urls, function() {
#             console.log("Bokeh: BokehJS plotting callback run at", now());
#             run_inline_js();
#           });
#         }
#       }(this));
#     </script>
#    mpg  cyl  displ   hp  weight  accel  yr  origin                       name
# 0   18    8    307  130    3504   12.0  70       1  chevrolet chevelle malibu
# 1   15    8    350  165    3693   11.5  70       1          buick skylark 320
# 2   18    8    318  150    3436   11.0  70       1         plymouth satellite
# 3   16    8    304  150    3433   12.0  70       1              amc rebel sst
# 4   17    8    302  140    3449   10.5  70       1                ford torino

# %% [markdown]
# ### Simple Bar Chart

# %%
p = Bar(df, 'cyl', values='mpg', title="Total MPG by CYL")
show(p)
# Out:
#     <div class="plotdiv" id="c7430ac8-e829-40c3-b8af-12623c3b015f"></div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined") {
#       window._bokeh_onload_callbacks = [];
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("c7430ac8-e829-40c3-b8af-12623c3b015f");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'c7430ac8-e829-40c3-b8af-12623c3b015f' but no matching script tag was found. ")
#       return false;
#     }var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"7199f130-cc1b-4ace-ba8b-a2af01aa8bf4": {"version": "0.11.0", "roots": {"root_ids": ["0f8aeea7-2924-48e3-9cad-7c1f53353878"], "references": [{"attributes": {"callback": null, "column_names": ["line_color", "line_alpha", "color", "fill_alpha", "height", "width", "y", "x"], "data": {"line_color": ["white"], "line_alpha": [1.0], "chart_index": [{"cyl": 8}], "color": ["#f22c40"], "fill_alpha": [0.8], "height": [1541.2000000000003], "width": [0.8], "y": [770.6000000000001], "x": ["8"], "cyl": [8]}}, "type": "ColumnDataSource", "id": "cb9ed614-81a1-4fb5-9a5a-932a661225c5"}, {"attributes": {"nonselection_glyph": null, "data_source": {"type": "ColumnDataSource", "id": "cb9ed614-81a1-4fb5-9a5a-932a661225c5"}, "selection_glyph": null, "hover_glyph": null, "glyph": {"type": "Rect", "id": "ed95e0d5-4761-4d94-8543-811c44ff105a"}}, "type": "GlyphRenderer", "id": "1f6d3f00-44aa-4102-bdf6-66070b42c545"}, {"attributes": {}, "type": "BasicTicker", "id": "79900314-3aac-4974-a8aa-cf9c1c4235eb"}, {"attributes": {"plot": {"subtype": "Chart", "type": "Plot", "id": "0f8aeea7-2924-48e3-9cad-7c1f53353878"}, "overlay": {"type": "BoxAnnotation", "id": "1efad9d2-eec2-485c-91d6-505d105d3faf"}}, "type": "BoxZoomTool", "id": "e0af10a0-9127-441e-91f1-95f1c938741b"}, {"attributes": {"line_color": {"value": "black"}, "line_alpha": {"value": 1.0}, "render_mode": "css", "bottom_units": "screen", "level": "overlay", "top_units": "screen", "fill_alpha": {"value": 0.5}, "plot": null, "left_units": "screen", "line_dash": [4, 4], "line_width": {"value": 2}, "right_units": "screen", "fill_color": {"value": "lightgrey"}}, "type": "BoxAnnotation", "id": "1efad9d2-eec2-485c-91d6-505d105d3faf"}, {"attributes": {"line_color": {"field": "line_color"}, "fill_color": {"field": "color"}, "fill_alpha": {"field": "fill_alpha"}, "height": {"units": "data", "field": "height"}, "width": {"units": "data", "field": "width"}, "y": {"field": "y"}, "x": {"field": "x"}}, "type": "Rect", "id": "c2e9607b-870c-491f-997a-c5215cc31c7f"}, {"attributes": {"callback": null, "column_names": ["line_color", "line_alpha", "color", "fill_alpha", "height", "width", "y", "x"], "data": {"line_color": ["white"], "line_alpha": [1.0], "chart_index": [{"cyl": 4}], "color": ["#f22c40"], "fill_alpha": [0.8], "height": [5827.500000000002], "width": [0.8], "y": [2913.750000000001], "x": ["4"], "cyl": [4]}}, "type": "ColumnDataSource", "id": "130ccca4-9a12-44e6-93dd-e12ccc4a9590"}, {"attributes": {"plot": {"subtype": "Chart", "type": "Plot", "id": "0f8aeea7-2924-48e3-9cad-7c1f53353878"}}, "type": "WheelZoomTool", "id": "1b7351fe-dba6-4140-b303-e9970a376115"}, {"attributes": {}, "type": "CategoricalTickFormatter", "id": "594ad7db-4a65-4b46-82e3-9d8007361260"}, {"attributes": {"nonselection_glyph": null, "data_source": {"type": "ColumnDataSource", "id": "130ccca4-9a12-44e6-93dd-e12ccc4a9590"}, "selection_glyph": null, "hover_glyph": null, "glyph": {"type": "Rect", "id": "34fe8c5e-a757-4b8f-bb84-f2fbdd079907"}}, "type": "GlyphRenderer", "id": "6333b3d3-8f06-45a2-b01b-bf083680e795"}, {"attributes": {"callback": null, "column_names": ["line_color", "line_alpha", "color", "fill_alpha", "height", "width", "y", "x"], "data": {"line_color": ["white"], "line_alpha": [1.0], "chart_index": [{"cyl": 5}], "color": ["#f22c40"], "fill_alpha": [0.8], "height": [82.1], "width": [0.8], "y": [41.05], "x": ["5"], "cyl": [5]}}, "type": "ColumnDataSource", "id": "58461862-3a26-411f-b277-b909f8b50dea"}, {"attributes": {"x_range": {"type": "FactorRange", "id": "9713b82e-0aeb-42c0-8739-825c4e3d27e0"}, "y_mapper_type": "auto", "title_text_font_size": {"value": "14pt"}, "title": "Total MPG by CYL", "y_range": {"type": "Range1d", "id": "6e96587a-0505-432f-aafe-c20e5023d164"}, "x_mapper_type": "auto", "yscale": "auto", "renderers": [{"type": "BoxAnnotation", "id": "1efad9d2-eec2-485c-91d6-505d105d3faf"}, {"type": "GlyphRenderer", "id": "1f6d3f00-44aa-4102-bdf6-66070b42c545"}, {"type": "GlyphRenderer", "id": "6333b ...

# %% [markdown]
# <img src='files/resources/ic_assignment_black_24dp_2x.png' align='left'>Try changing the title of the plot.  Bring up the help and find out how to compute the Mean mpg rather than Sum.  Can you find a way to change the color of the bars to blue?

# %% [markdown]
# ### Grouped Bars

# %%
p = Bar(df, label='yr', values='mpg', agg='mean', group='origin',
        title="Mean MPG by YR, grouped by ORIGIN", legend='top_right')

show(p)
# Out:
#     <div class="plotdiv" id="1d4216db-18c9-476b-94bc-08a46bf08cf6"></div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined") {
#       window._bokeh_onload_callbacks = [];
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("1d4216db-18c9-476b-94bc-08a46bf08cf6");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '1d4216db-18c9-476b-94bc-08a46bf08cf6' but no matching script tag was found. ")
#       return false;
#     }var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"4e6c328e-8619-4de2-8a09-68441ecdfc0c": {"version": "0.11.0", "roots": {"root_ids": ["0f8aeea7-2924-48e3-9cad-7c1f53353878", "294416bc-79e2-4f08-a0c4-2ee9819a273b"], "references": [{"attributes": {"line_color": {"field": "line_color"}, "fill_color": {"field": "color"}, "fill_alpha": {"field": "fill_alpha"}, "height": {"units": "data", "field": "height"}, "width": {"units": "data", "field": "width"}, "y": {"field": "y"}, "x": {"field": "x"}}, "type": "Rect", "id": "7929d1e4-9d35-4ee9-80b7-71477968976d"}, {"attributes": {}, "type": "ToolEvents", "id": "e8caa030-b355-42d3-910c-b6786691840a"}, {"attributes": {"line_color": {"field": "line_color"}, "fill_color": {"field": "color"}, "fill_alpha": {"field": "fill_alpha"}, "height": {"units": "data", "field": "height"}, "width": {"units": "data", "field": "width"}, "y": {"field": "y"}, "x": {"field": "x"}}, "type": "Rect", "id": "c10b1675-258d-48ce-93f5-4e1424008719"}, {"attributes": {"nonselection_glyph": null, "data_source": {"type": "ColumnDataSource", "id": "58461862-3a26-411f-b277-b909f8b50dea"}, "selection_glyph": null, "hover_glyph": null, "glyph": {"type": "Rect", "id": "c82931ad-a343-437c-b707-edae83def5fd"}}, "type": "GlyphRenderer", "id": "f74e46dc-0af9-484e-91de-c14201c3253c"}, {"attributes": {"line_color": {"field": "line_color"}, "fill_color": {"field": "color"}, "fill_alpha": {"field": "fill_alpha"}, "height": {"units": "data", "field": "height"}, "width": {"units": "data", "field": "width"}, "y": {"field": "y"}, "x": {"field": "x"}}, "type": "Rect", "id": "ca5a3966-f697-40d5-8df0-e6b0565fe4b2"}, {"attributes": {"line_color": {"field": "line_color"}, "fill_color": {"field": "color"}, "fill_alpha": {"field": "fill_alpha"}, "height": {"units": "data", "field": "height"}, "width": {"units": "data", "field": "width"}, "y": {"field": "y"}, "x": {"field": "x"}}, "type": "Rect", "id": "5b6c388f-8ab1-4ac7-9816-1b45e52741d8"}, {"attributes": {"nonselection_glyph": null, "data_source": {"type": "ColumnDataSource", "id": "31424213-2d2b-410f-95e9-0b98a0a5323b"}, "selection_glyph": null, "hover_glyph": null, "glyph": {"type": "Rect", "id": "39aa6d3c-0d56-42e2-a4a1-f2cab7acf960"}}, "type": "GlyphRenderer", "id": "686985ed-f282-4b38-99ac-673377709b0f"}, {"attributes": {"nonselection_glyph": null, "data_source": {"type": "ColumnDataSource", "id": "b363482b-ef5f-43c4-8a4f-cc352a56e3f4"}, "selection_glyph": null, "hover_glyph": null, "glyph": {"type": "Rect", "id": "b47e1475-0da3-41f4-940d-a51350282d3c"}}, "type": "GlyphRenderer", "id": "19be5afd-ae70-4544-90ff-558f394b33ac"}, {"attributes": {"callback": null, "column_names": ["line_color", "line_alpha", "color", "fill_alpha", "height", "width", "y", "x"], "data": {"line_color": ["white"], "line_alpha": [1.0], "chart_index": [{"origin": 3, "yr": 78}], "color": ["#407ee7"], "fill_alpha": [0.8], "height": [29.687499999999996], "width": [0.2], "y": [14.843749999999998], "x": ["78:0.5"], "yr": [78], "origin": [3]}}, "type": "ColumnDataSource", "id": "dfaa7f53-543b-4714-a4be-ae340183eaf2"}, {"attributes": {"line_color": {"field": "line_color"}, "fill_color": {"field": "color"}, "fill_alpha": {"field": "fill_alpha"}, "height": {"units": "data", "field": "height"}, "width": {"units": "data", "field": "width"}, "y": {"field": "y"}, "x": {"field": "x"}}, "type": "Rect", "id": "fdf37d98-4742-4e49-8650-11f00434f419"}, {"attributes": {"callback": null, "factors": ["70", "71", "72", "73", "74", "75", "76", "77", "78", "79", "80", "81", "82"]}, "type": "FactorRange", "id": "a426486c-15aa-4948-9900-ba75623736ba"}, {"attributes": {"line_color": {"field": "line_color"}, "fill_color": {"field": "color"}, "fill_alpha": {"field": "fill_alpha"}, "height": {"units": "data", "field": "height"}, "width": {"units": "data", "field": "width"}, "y": {"field": "y"}, "x": {"field": "x"}}, "type": "Rect", "id": "dc7c2a32-9923-4b16-92a1-d0cdf3817469"}, {"attributes": {"plot": {"subtype": "Chart", "type": "Plot", "id": "294416bc-79e2-4f08-a0 ...

# %% [markdown]
# ### Stacked Bars

# %%
p = Bar(df, label='cyl', values='mpg', agg='count', stack='origin',
        title="Count of observations by CYL, stacked by ORIGIN", legend='top_right')
show(p)
# Out:
#     <div class="plotdiv" id="a90c0d91-eeb2-4e66-9d1d-13d1a984a29e"></div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined") {
#       window._bokeh_onload_callbacks = [];
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("a90c0d91-eeb2-4e66-9d1d-13d1a984a29e");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'a90c0d91-eeb2-4e66-9d1d-13d1a984a29e' but no matching script tag was found. ")
#       return false;
#     }var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"b0db6afc-186f-47ac-ad12-6acb5c02f58e": {"version": "0.11.0", "roots": {"root_ids": ["0f8aeea7-2924-48e3-9cad-7c1f53353878", "294416bc-79e2-4f08-a0c4-2ee9819a273b", "305b2f8d-e400-42da-a5d7-8995387ca29e"], "references": [{"attributes": {"callback": null, "column_names": ["line_color", "line_alpha", "color", "fill_alpha", "height", "width", "y", "x"], "data": {"line_color": ["white"], "line_alpha": [1.0], "chart_index": [{"origin": 2, "cyl": 6}], "color": ["#5ab738"], "fill_alpha": [0.8], "height": [4.0], "width": [0.8], "y": [81.0], "x": ["6"], "origin": [2], "cyl": [6]}}, "type": "ColumnDataSource", "id": "9b4ae876-d60c-4b99-bc1c-0e632264cf28"}, {"attributes": {}, "type": "ToolEvents", "id": "e8caa030-b355-42d3-910c-b6786691840a"}, {"attributes": {"plot": {"subtype": "Chart", "type": "Plot", "id": "0f8aeea7-2924-48e3-9cad-7c1f53353878"}}, "type": "ResetTool", "id": "9e8eca33-adf2-471e-9a46-3da3f6be5914"}, {"attributes": {"plot": {"subtype": "Chart", "type": "Plot", "id": "305b2f8d-e400-42da-a5d7-8995387ca29e"}}, "type": "PanTool", "id": "2e9a2719-4723-4879-9627-eaa505d769fd"}, {"attributes": {"line_color": {"field": "line_color"}, "fill_color": {"field": "color"}, "fill_alpha": {"field": "fill_alpha"}, "height": {"units": "data", "field": "height"}, "width": {"units": "data", "field": "width"}, "y": {"field": "y"}, "x": {"field": "x"}}, "type": "Rect", "id": "7929d1e4-9d35-4ee9-80b7-71477968976d"}, {"attributes": {"callback": null, "column_names": ["line_color", "line_alpha", "color", "fill_alpha", "height", "width", "y", "x"], "data": {"line_color": ["white"], "line_alpha": [1.0], "chart_index": [{"origin": 1, "cyl": 8}], "color": ["#f22c40"], "fill_alpha": [0.8], "height": [103.0], "width": [0.8], "y": [51.5], "x": ["8"], "origin": [1], "cyl": [8]}}, "type": "ColumnDataSource", "id": "b54d0526-a031-4685-9140-37a83c25ab71"}, {"attributes": {"nonselection_glyph": null, "data_source": {"type": "ColumnDataSource", "id": "58461862-3a26-411f-b277-b909f8b50dea"}, "selection_glyph": null, "hover_glyph": null, "glyph": {"type": "Rect", "id": "c82931ad-a343-437c-b707-edae83def5fd"}}, "type": "GlyphRenderer", "id": "f74e46dc-0af9-484e-91de-c14201c3253c"}, {"attributes": {"nonselection_glyph": null, "data_source": {"type": "ColumnDataSource", "id": "a91b2258-ce4c-41be-8a1d-9026b8e16d04"}, "selection_glyph": null, "hover_glyph": null, "glyph": {"type": "Rect", "id": "655dd23e-b258-4c15-9863-4e3f506a0500"}}, "type": "GlyphRenderer", "id": "ade93e18-7f50-4636-be41-e111534bbb12"}, {"attributes": {"line_color": {"field": "line_color"}, "fill_color": {"field": "color"}, "fill_alpha": {"field": "fill_alpha"}, "height": {"units": "data", "field": "height"}, "width": {"units": "data", "field": "width"}, "y": {"field": "y"}, "x": {"field": "x"}}, "type": "Rect", "id": "78e20b18-a101-4370-9eea-52a1ba95699c"}, {"attributes": {"line_color": {"field": "line_color"}, "fill_color": {"field": "color"}, "fill_alpha": {"field": "fill_alpha"}, "height": {"units": "data", "field": "height"}, "width": {"units": "data", "field": "width"}, "y": {"field": "y"}, "x": {"field": "x"}}, "type": "Rect", "id": "ca5a3966-f697-40d5-8df0-e6b0565fe4b2"}, {"attributes": {"line_color": {"field": "line_color"}, "fill_color": {"field": "color"}, "fill_alpha": {"field": "fill_alpha"}, "height": {"units": "data", "field": "height"}, "width": {"units": "data", "field": "width"}, "y": {"field": "y"}, "x": {"field": "x"}}, "type": "Rect", "id": "3f2856ff-cebd-43ae-b5a4-c29ecbaacb98"}, {"attributes": {"line_color": {"field": "line_color"}, "fill_color": {"field": "color"}, "fill_alpha": {"field": "fill_alpha"}, "height": {"units": "data", "field": "height"}, "width": {"units": "data", "field": "width"}, "y": {"field": "y"}, "x": {"field": "x"}}, "type": "Rect", "id": "5b6c388f-8ab1-4ac7-9816-1b45e52741d8"}, {"attributes": {"nonselection_glyph": null, "data_source": {"type": "ColumnDataSource", "id": "31424213-2d2b-410f-95e9-0b98a0a5323b"}, "selection_ ...

# %% [markdown]
# ### Line Chart
#
# Simple line chart - first we group by the yr and compute mean of each value.

# %%
from bokeh.charts import Line

df_mean = df.groupby("yr", as_index=False).mean()

line = Line(data=df_mean, x='yr', y='mpg')
show(line)
# Out:
#     <div class="plotdiv" id="be81412a-1bc9-44cb-b4d6-acbdeea91460"></div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined") {
#       window._bokeh_onload_callbacks = [];
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("be81412a-1bc9-44cb-b4d6-acbdeea91460");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'be81412a-1bc9-44cb-b4d6-acbdeea91460' but no matching script tag was found. ")
#       return false;
#     }var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"b6f6cf1c-b828-4850-a6d2-24a4d9c33274": {"version": "0.11.0", "roots": {"root_ids": ["0f8aeea7-2924-48e3-9cad-7c1f53353878", "294416bc-79e2-4f08-a0c4-2ee9819a273b", "305b2f8d-e400-42da-a5d7-8995387ca29e", "5949e436-17ee-4a5d-ba3c-9762f2ea5a25"], "references": [{"attributes": {"line_color": {"field": "line_color"}, "fill_color": {"field": "color"}, "fill_alpha": {"field": "fill_alpha"}, "height": {"units": "data", "field": "height"}, "width": {"units": "data", "field": "width"}, "y": {"field": "y"}, "x": {"field": "x"}}, "type": "Rect", "id": "3f2856ff-cebd-43ae-b5a4-c29ecbaacb98"}, {"attributes": {}, "type": "ToolEvents", "id": "e8caa030-b355-42d3-910c-b6786691840a"}, {"attributes": {"callback": null, "column_names": ["line_color", "line_alpha", "color", "fill_alpha", "height", "width", "y", "x"], "data": {"line_color": ["white"], "line_alpha": [1.0], "chart_index": [{"origin": 2, "yr": 76}], "color": ["#5ab738"], "fill_alpha": [0.8], "height": [24.25], "width": [0.2], "y": [12.125], "x": ["76:0.75"], "yr": [76], "origin": [2]}}, "type": "ColumnDataSource", "id": "eb68163f-d37c-43c0-80a2-c7d19e2a35f1"}, {"attributes": {"line_color": {"field": "line_color"}, "fill_color": {"field": "color"}, "fill_alpha": {"field": "fill_alpha"}, "height": {"units": "data", "field": "height"}, "width": {"units": "data", "field": "width"}, "y": {"field": "y"}, "x": {"field": "x"}}, "type": "Rect", "id": "c10b1675-258d-48ce-93f5-4e1424008719"}, {"attributes": {"plot": {"subtype": "Chart", "type": "Plot", "id": "305b2f8d-e400-42da-a5d7-8995387ca29e"}}, "type": "PanTool", "id": "2e9a2719-4723-4879-9627-eaa505d769fd"}, {"attributes": {"line_color": {"field": "line_color"}, "fill_color": {"field": "color"}, "fill_alpha": {"field": "fill_alpha"}, "height": {"units": "data", "field": "height"}, "width": {"units": "data", "field": "width"}, "y": {"field": "y"}, "x": {"field": "x"}}, "type": "Rect", "id": "7929d1e4-9d35-4ee9-80b7-71477968976d"}, {"attributes": {"nonselection_glyph": null, "data_source": {"type": "ColumnDataSource", "id": "58461862-3a26-411f-b277-b909f8b50dea"}, "selection_glyph": null, "hover_glyph": null, "glyph": {"type": "Rect", "id": "c82931ad-a343-437c-b707-edae83def5fd"}}, "type": "GlyphRenderer", "id": "f74e46dc-0af9-484e-91de-c14201c3253c"}, {"attributes": {"callback": null, "end": 83.2, "start": 68.8}, "type": "Range1d", "id": "f007e6bb-0577-4038-813a-349e196ef04f"}, {"attributes": {"line_color": {"field": "line_color"}, "fill_color": {"field": "color"}, "fill_alpha": {"field": "fill_alpha"}, "height": {"units": "data", "field": "height"}, "width": {"units": "data", "field": "width"}, "y": {"field": "y"}, "x": {"field": "x"}}, "type": "Rect", "id": "78e20b18-a101-4370-9eea-52a1ba95699c"}, {"attributes": {"line_color": {"field": "line_color"}, "fill_color": {"field": "color"}, "fill_alpha": {"field": "fill_alpha"}, "height": {"units": "data", "field": "height"}, "width": {"units": "data", "field": "width"}, "y": {"field": "y"}, "x": {"field": "x"}}, "type": "Rect", "id": "ca5a3966-f697-40d5-8df0-e6b0565fe4b2"}, {"attributes": {"callback": null, "column_names": ["line_color", "line_alpha", "color", "fill_alpha", "height", "width", "y", "x"], "data": {"line_color": ["white"], "line_alpha": [1.0], "chart_index": [{"origin": 2, "cyl": 6}], "color": ["#5ab738"], "fill_alpha": [0.8], "height": [4.0], "width": [0.8], "y": [81.0], "x": ["6"], "origin": [2], "cyl": [6]}}, "type": "ColumnDataSource", "id": "9b4ae876-d60c-4b99-bc1c-0e632264cf28"}, {"attributes": {"line_color": {"field": "line_color"}, "fill_color": {"field": "color"}, "fill_alpha": {"field": "fill_alpha"}, "height": {"units": "data", "field": "height"}, "width": {"units": "data", "field": "width"}, "y": {"field": "y"}, "x": {"field": "x"}}, "type": "Rect", "id": "5b6c388f-8ab1-4ac7-9816-1b45e52741d8"}, {"attributes": {"nonselection_glyph": null, "data_source": {"type": "ColumnDataSource", "id": "31424213-2d2b-410f-95e9-0b98a0a5323b"}, "selection ...

# %% [markdown]
# <img src='files/resources/ic_assignment_black_24dp_2x.png' align='left'>Can you find out how to add a second line showing the mean number of cylinders to the plot? The data frame already includes the value - you just need a change to the bokeh Line() call.

# %% [markdown]
# ### Scatter Chart
#
# Simple, color mapped to category, shape mapped to category

# %%
from bokeh.charts import Scatter

scatter = Scatter(data=df, x='mpg',y='weight', color ='cyl', legend='top_left')
show(scatter)
# Out:
#     <div class="plotdiv" id="f2ed0ce9-99ad-4a34-ab79-2b9fad089f18"></div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined") {
#       window._bokeh_onload_callbacks = [];
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("f2ed0ce9-99ad-4a34-ab79-2b9fad089f18");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'f2ed0ce9-99ad-4a34-ab79-2b9fad089f18' but no matching script tag was found. ")
#       return false;
#     }var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"80241702-3e61-4db1-aeb2-bf72c617c456": {"version": "0.11.0", "roots": {"root_ids": ["0f8aeea7-2924-48e3-9cad-7c1f53353878", "294416bc-79e2-4f08-a0c4-2ee9819a273b", "305b2f8d-e400-42da-a5d7-8995387ca29e", "5949e436-17ee-4a5d-ba3c-9762f2ea5a25", "2e5eb7d9-c368-4e0d-a7ad-a163065780dd"], "references": [{"attributes": {"line_color": {"field": "line_color"}, "fill_color": {"field": "color"}, "fill_alpha": {"field": "fill_alpha"}, "height": {"units": "data", "field": "height"}, "width": {"units": "data", "field": "width"}, "y": {"field": "y"}, "x": {"field": "x"}}, "type": "Rect", "id": "3f2856ff-cebd-43ae-b5a4-c29ecbaacb98"}, {"attributes": {}, "type": "ToolEvents", "id": "e8caa030-b355-42d3-910c-b6786691840a"}, {"attributes": {"plot": {"subtype": "Chart", "type": "Plot", "id": "5949e436-17ee-4a5d-ba3c-9762f2ea5a25"}}, "type": "WheelZoomTool", "id": "81d53400-e494-49c4-a531-2e24f651c964"}, {"attributes": {"plot": {"subtype": "Chart", "type": "Plot", "id": "0f8aeea7-2924-48e3-9cad-7c1f53353878"}}, "type": "ResetTool", "id": "9e8eca33-adf2-471e-9a46-3da3f6be5914"}, {"attributes": {"plot": {"subtype": "Chart", "type": "Plot", "id": "305b2f8d-e400-42da-a5d7-8995387ca29e"}}, "type": "PanTool", "id": "2e9a2719-4723-4879-9627-eaa505d769fd"}, {"attributes": {"line_color": {"field": "line_color"}, "fill_color": {"field": "color"}, "fill_alpha": {"field": "fill_alpha"}, "height": {"units": "data", "field": "height"}, "width": {"units": "data", "field": "width"}, "y": {"field": "y"}, "x": {"field": "x"}}, "type": "Rect", "id": "7929d1e4-9d35-4ee9-80b7-71477968976d"}, {"attributes": {"nonselection_glyph": null, "data_source": {"type": "ColumnDataSource", "id": "58461862-3a26-411f-b277-b909f8b50dea"}, "selection_glyph": null, "hover_glyph": null, "glyph": {"type": "Rect", "id": "c82931ad-a343-437c-b707-edae83def5fd"}}, "type": "GlyphRenderer", "id": "f74e46dc-0af9-484e-91de-c14201c3253c"}, {"attributes": {"callback": null, "end": 83.2, "start": 68.8}, "type": "Range1d", "id": "f007e6bb-0577-4038-813a-349e196ef04f"}, {"attributes": {"line_color": {"field": "line_color"}, "fill_color": {"field": "color"}, "fill_alpha": {"field": "fill_alpha"}, "height": {"units": "data", "field": "height"}, "width": {"units": "data", "field": "width"}, "y": {"field": "y"}, "x": {"field": "x"}}, "type": "Rect", "id": "78e20b18-a101-4370-9eea-52a1ba95699c"}, {"attributes": {"line_color": {"field": "line_color"}, "fill_color": {"field": "color"}, "fill_alpha": {"field": "fill_alpha"}, "height": {"units": "data", "field": "height"}, "width": {"units": "data", "field": "width"}, "y": {"field": "y"}, "x": {"field": "x"}}, "type": "Rect", "id": "ca5a3966-f697-40d5-8df0-e6b0565fe4b2"}, {"attributes": {"callback": null, "column_names": ["line_color", "line_alpha", "color", "fill_alpha", "height", "width", "y", "x"], "data": {"line_color": ["white"], "line_alpha": [1.0], "chart_index": [{"origin": 2, "cyl": 6}], "color": ["#5ab738"], "fill_alpha": [0.8], "height": [4.0], "width": [0.8], "y": [81.0], "x": ["6"], "origin": [2], "cyl": [6]}}, "type": "ColumnDataSource", "id": "9b4ae876-d60c-4b99-bc1c-0e632264cf28"}, {"attributes": {"line_color": {"field": "line_color"}, "fill_color": {"field": "color"}, "fill_alpha": {"field": "fill_alpha"}, "height": {"units": "data", "field": "height"}, "width": {"units": "data", "field": "width"}, "y": {"field": "y"}, "x": {"field": "x"}}, "type": "Rect", "id": "5b6c388f-8ab1-4ac7-9816-1b45e52741d8"}, {"attributes": {"nonselection_glyph": null, "data_source": {"type": "ColumnDataSource", "id": "31424213-2d2b-410f-95e9-0b98a0a5323b"}, "selection_glyph": null, "hover_glyph": null, "glyph": {"type": "Rect", "id": "39aa6d3c-0d56-42e2-a4a1-f2cab7acf960"}}, "type": "GlyphRenderer", "id": "686985ed-f282-4b38-99ac-673377709b0f"}, {"attributes": {"nonselection_glyph": null, "data_source": {"type": "ColumnDataSource", "id": "b363482b-ef5f-43c4-8a4f-cc352a56e3f4"}, "selection_glyph": null, "hover_glyph": null, "glyph": {" ...

# %% [markdown]
# <img src='files/resources/ic_assignment_black_24dp_2x.png' align='left'>Can you fix the legend placement problem?

# %% [markdown]
# ### Boxplot
#
# Show the spread of the data.

# %%
from bokeh.charts import BoxPlot

boxplot = BoxPlot(df,label='cyl',values='mpg')

show(boxplot)
# Out:
#     <div class="plotdiv" id="8ad23944-9c2c-48cc-b758-6c15fb38a9f8"></div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined") {
#       window._bokeh_onload_callbacks = [];
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("8ad23944-9c2c-48cc-b758-6c15fb38a9f8");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '8ad23944-9c2c-48cc-b758-6c15fb38a9f8' but no matching script tag was found. ")
#       return false;
#     }var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"ad156ba5-562a-4da6-9bad-6e5a3c146615": {"version": "0.11.0", "roots": {"root_ids": ["0f8aeea7-2924-48e3-9cad-7c1f53353878", "294416bc-79e2-4f08-a0c4-2ee9819a273b", "305b2f8d-e400-42da-a5d7-8995387ca29e", "5949e436-17ee-4a5d-ba3c-9762f2ea5a25", "2e5eb7d9-c368-4e0d-a7ad-a163065780dd", "a14268ea-0d90-4db3-918f-e43b8c1200fc"], "references": [{"attributes": {"callback": null, "column_names": ["line_color", "line_alpha", "color", "fill_alpha", "height", "width", "y", "x"], "data": {"line_color": ["white"], "line_alpha": [1.0], "chart_index": [{"origin": 2, "yr": 76}], "color": ["#5ab738"], "fill_alpha": [0.8], "height": [24.25], "width": [0.2], "y": [12.125], "x": ["76:0.75"], "yr": [76], "origin": [2]}}, "type": "ColumnDataSource", "id": "eb68163f-d37c-43c0-80a2-c7d19e2a35f1"}, {"attributes": {"line_color": {"field": "line_color"}, "fill_color": {"field": "color"}, "fill_alpha": {"field": "fill_alpha"}, "height": {"units": "data", "field": "height"}, "width": {"units": "data", "field": "width"}, "y": {"field": "y"}, "x": {"field": "x"}}, "type": "Rect", "id": "ca5a3966-f697-40d5-8df0-e6b0565fe4b2"}, {"attributes": {"plot": {"subtype": "Chart", "type": "Plot", "id": "2e5eb7d9-c368-4e0d-a7ad-a163065780dd"}}, "type": "PanTool", "id": "81cac780-6e43-4945-9bb7-dcd49341479f"}, {"attributes": {"nonselection_glyph": null, "data_source": {"type": "ColumnDataSource", "id": "31424213-2d2b-410f-95e9-0b98a0a5323b"}, "selection_glyph": null, "hover_glyph": null, "glyph": {"type": "Rect", "id": "39aa6d3c-0d56-42e2-a4a1-f2cab7acf960"}}, "type": "GlyphRenderer", "id": "686985ed-f282-4b38-99ac-673377709b0f"}, {"attributes": {"line_color": {"field": "line_color"}, "fill_color": {"field": "color"}, "fill_alpha": {"field": "fill_alpha"}, "height": {"units": "data", "field": "height"}, "width": {"units": "data", "field": "width"}, "y": {"field": "y"}, "x": {"field": "x"}}, "type": "Rect", "id": "ed95e0d5-4761-4d94-8543-811c44ff105a"}, {"attributes": {}, "type": "BasicTicker", "id": "c3a2a1a6-0e11-40bb-832f-39ba94f46dc2"}, {"attributes": {"plot": {"subtype": "Chart", "type": "Plot", "id": "305b2f8d-e400-42da-a5d7-8995387ca29e"}, "ticker": {"type": "BasicTicker", "id": "52f2b5d9-a071-49c3-805d-1c9ad255fd76"}, "dimension": 1}, "type": "Grid", "id": "626d495a-7918-4218-a8b8-55616ee8d8ba"}, {"attributes": {"nonselection_glyph": null, "data_source": {"type": "ColumnDataSource", "id": "8db8deea-af46-4ed8-8d94-b06b08a247b9"}, "selection_glyph": null, "hover_glyph": null, "glyph": {"type": "Rect", "id": "fdf37d98-4742-4e49-8650-11f00434f419"}}, "type": "GlyphRenderer", "id": "f3b8d2a6-0611-40b6-9d77-0cbeea37bf2c"}, {"attributes": {"nonselection_glyph": null, "data_source": {"type": "ColumnDataSource", "id": "717938d6-f210-46d1-8b11-d0786863f1a6"}, "selection_glyph": null, "hover_glyph": null, "glyph": {"type": "Rect", "id": "abbf97e3-63b9-4b0e-9ff5-00d87c8553d5"}}, "type": "GlyphRenderer", "id": "aca6ec25-5d83-4bf3-87c7-05fc428bf071"}, {"attributes": {"nonselection_glyph": null, "data_source": {"type": "ColumnDataSource", "id": "22266660-f81e-4ad2-8c6c-fac0f1a167ae"}, "selection_glyph": null, "hover_glyph": null, "glyph": {"type": "Rect", "id": "df96ef39-3b6b-4f5a-9d97-b6dec7e0fd5e"}}, "type": "GlyphRenderer", "id": "6e7bd790-7fc8-462e-918e-8f3d8b9a3aea"}, {"attributes": {"plot": {"subtype": "Chart", "type": "Plot", "id": "0f8aeea7-2924-48e3-9cad-7c1f53353878"}}, "type": "HelpTool", "id": "f9b5d3c8-f61d-4e28-9063-fcb2ebdc6dbe"}, {"attributes": {"plot": {"subtype": "Chart", "type": "Plot", "id": "5949e436-17ee-4a5d-ba3c-9762f2ea5a25"}}, "type": "ResizeTool", "id": "28032cf5-e9ff-4320-93e9-5e0f49ea5fa0"}, {"attributes": {"callback": null, "column_names": ["x_values", "y_values"], "data": {"x_values": [70, 71, 72, 73, 74, 75, 76, 77, 78, 79, 80, 81, 82], "chart_index": [null, null, null, null, null, null, null, null, null, null, null, null, null], "y_values": [17.689655172413794, 21.11111111111111, 18.714285714285715, 17.1, 22.76923076 ...

# %% [markdown]
# <img src='files/resources/ic_assignment_black_24dp_2x.png' align='left'>Find a way to remove the outliers from the plot.
# Can you change the color of the box?

# %% [markdown]
# ### Where now?
#
# Going from here - browse over to the [bokeh docs](http://bokeh.pydata.org/en/latest/docs/user_guide.html) and start exploring some of the lower level bokeh.plotting libraries and the [gallery](http://bokeh.pydata.org/en/latest/docs/gallery.html) for inspiration.
#
# Remember - [Pandas](http://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.html#pandas.DataFrame) is your friend.  Get that data into Pandas and Bokeh will play very nicely.  Plus Pandas is a great API for working with data frames.  It is worth exploring and learning.
#
# Most the time the default plots will suffice.  It can take many days to get publication ready plots - make sure you really need that tweak to the plot before losing days of your life!
